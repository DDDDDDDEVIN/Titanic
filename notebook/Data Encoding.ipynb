# %%
import pandas as pd

# %%
train_X = pd.read_csv('../data/curated/cleaned_train_X.csv')
val_X = pd.read_csv('../data/curated/cleaned_val_X.csv')
test_X = pd.read_csv('../data/curated/cleaned_test_X.csv')

# %% [markdown]
# ## One-hot Encode Categorical Data

# %%
encoded_train_X = pd.get_dummies(train_X, columns=['Sex', 'Embarked', 'ticket_prefix', 'title', 'family_name'])
encoded_val_X = pd.get_dummies(val_X, columns=['Sex', 'Embarked', 'ticket_prefix', 'title', 'family_name'])
encoded_test_X = pd.get_dummies(test_X, columns=['Sex', 'Embarked', 'ticket_prefix', 'title', 'family_name'])

# %%
encoded_train_X
# Out:
#      Pclass   Age  SibSp  Parch      Fare  Sex_female  Sex_male  Embarked_C  \
# 0         1  45.5      0      0   28.5000       False      True       False
# 1         2  23.0      0      0   13.0000       False      True       False
# 2         3  32.0      0      0    7.9250       False      True       False
# 3         3  26.0      1      0    7.8542       False      True       False
# 4         3   6.0      4      2   31.2750        True     False       False
# ..      ...   ...    ...    ...       ...         ...       ...         ...
# 707       3  21.0      0      0    7.6500        True     False       False
# 708       1  28.0      0      0   31.0000       False      True       False
# 709       3  41.0      2      0   14.1083       False      True       False
# 710       1  14.0      1      2  120.0000        True     False       False
# 711       1  21.0      0      1   77.2875       False      True       False
#
#      Embarked_Q  Embarked_S  ...  family_name_Youseff  family_name_Yousif  \
# 0         False        True  ...                False               False
# 1         False        True  ...                False               False
# 2         False        True  ...                False               False
# 3         False        True  ...                False               False
# 4         False        True  ...                False               False
# ..          ...         ...  ...                  ...                 ...
# 707       False        True  ...                False               False
# 708       False        True  ...                False               False
# 709       False        True  ...                False               False
# 710       False        True  ...                False               False
# 711       False        True  ...                False               False
#
#      family_name_Yousseff  family_name_Yrois  family_name_Zabour  \
# 0                   False              False               False
# 1                   False              False               False
# 2                   False              False               False
# 3                   False              False               False
# 4                   False              False               False
# ..                    ...                ...                 ...
# 707                 False              False               False
# 708                 False              False               False
# 709                 False              False               False
# 710                 False              False               False
# 711                 False              False               False
#
#      family_name_de Messemaeker  family_name_de Pelsmaeker  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
# ..                          ...                        ...
# 707                       False                      False
# 708                       False                      False
# 709                       False                      False
# 710                       False                      False
# 711                       False                      False
#
#      family_name_del Carlo  family_name_van Billiard  \
# 0                    False                     False
# 1                    False                     False
# 2                    False                     False
# 3                    False                     False
# 4                    False                     False
# ..                     ...                       ...
# 707                  False                     False
# 708                  False                     False
# 709                  False                     False
# 710                  False                     False
# 711                  False                     False
#
#      family_name_van Melkebeke
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ..                         ...
# 707                      False
# 708                      False
# 709                      False
# 710                      False
# 711                      False
#
# [712 rows x 617 columns]

# %%
for feature in encoded_test_X.columns:
    if encoded_test_X[feature].isna().sum() > 0:
        print(feature)

# %% [markdown]
# ### PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
def get_pca(encoded_train_X):
    scaler = StandardScaler()
    scaled_train_X = scaler.fit_transform(encoded_train_X)
    pca = PCA(n_components=8)
    principal_components = pca.fit_transform(scaled_train_X)
    principal_df = pd.DataFrame(data=principal_components)
    return principal_df

# %%
principal_train_df = get_pca(encoded_train_X)
principal_val_df = get_pca(encoded_val_X)
principal_test_df = get_pca(encoded_test_X)

# %%
principal_train_df.to_csv('../data/curated/final_train_X.csv',index=False)
principal_val_df.to_csv('../data/curated/final_val_X.csv', index=False)
principal_test_df.to_csv('../data/curated/final_test_X.csv', index=False)

# %%
principal_train_df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -1.724223  1.068534 -0.273963  1.620942 -0.532684 -0.053457  0.385098
# 1   -1.826783 -0.047793 -0.149065  0.354428 -0.290857 -0.246937 -0.171269
# 2   -2.777715 -0.605869 -0.933386  0.263556 -0.904787 -0.705638 -1.045576
# 3   -1.904198 -0.777238  0.037681 -0.001763 -0.104553 -0.165943  0.203606
# 4    3.220837 -3.248682  0.933805 -0.244716 -0.050388 -0.264065  0.201226
# ..        ...       ...       ...       ...       ...       ...       ...
# 707  2.155485 -1.246704 -2.225635 -0.772080 -0.013753 -0.505448  0.060322
# 708 -1.605293  0.671980  0.026862  1.109573 -0.519891 -0.272976 -0.105279
# 709 -1.843127 -0.710988  0.187378  0.357637 -0.138563 -0.063199  0.545303
# 710  3.302133 -0.575631  0.249102  1.495337 -0.659151  0.533307  0.023883
# 711 -1.083137  0.511536  0.803406  1.515017 -0.656676 -0.254167 -0.191005
#
#             7
# 0   -0.240100
# 1    0.237109
# 2   -1.741810
# 3    0.074465
# 4    0.287618
# ..        ...
# 707  0.536728
# 708  0.023226
# 709 -0.077438
# 710  0.439988
# 711  0.034579
#
# [712 rows x 8 columns]
