# %%
import pandas as pd
import warnings
import sys

# %%
warnings.filterwarnings('ignore')

# %%
sys.path.append('../../privatePackage')

# %%
from DevinMengTuner import DevinMengTuner

# %%
tunable_parameters = {
    'n_neighbors': (1, 5, 9, 17, 33, 65),
    'metric': ('euclidean', 'manhattan', 'chebyshev'),
    'weights': ('distance', 'uniform'),
}

# %%
non_tunable_parameters = {
}

# %%
train_X = pd.read_csv('../../data/curated/final_train_X.csv')
train_Y = pd.read_csv('../../data/curated/train_Y.csv')
val_X = pd.read_csv('../../data/curated/final_val_X.csv')
val_Y = pd.read_csv('../../data/curated/val_Y.csv')

# %%
from sklearn.neighbors import KNeighborsClassifier as clf

# %%
model = clf()

# %%
tuner = DevinMengTuner()
tuner.set_data(train_X = train_X, train_Y = train_Y, test_X = val_X, test_Y = val_Y)
tuner.set_model(model=model, model_type='Classification', model_name='KNN')
tuner.set_parameters(tunable_parameters=tunable_parameters, non_tunable_parameters=non_tunable_parameters)
# Out:
# DevinMengTuner initialised

# %%
tuner.tune()
# Out:
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 1; metric: euclidean; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7262569832402235; F1-Score: 0.6754966887417219;
#
# Best Performance Metrics:
# Accuracy: 0.7262569832402235; F1-Score: 0.6754966887417219;
# Already tuned 1 out of 36 in total
# Progress: 2.78%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 1; metric: euclidean; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.7262569832402235; F1-Score: 0.6754966887417219;
#
# Best Performance Metrics:
# Accuracy: 0.7262569832402235; F1-Score: 0.6754966887417219;
# Already tuned 2 out of 36 in total
# Progress: 5.56%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 1; metric: manhattan; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7262569832402235; F1-Score: 0.6754966887417219;
#
# Best Performance Metrics:
# Accuracy: 0.7262569832402235; F1-Score: 0.6754966887417219;
# Already tuned 3 out of 36 in total
# Progress: 8.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 1; metric: manhattan; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.7262569832402235; F1-Score: 0.6754966887417219;
#
# Best Performance Metrics:
# Accuracy: 0.7262569832402235; F1-Score: 0.6754966887417219;
# Already tuned 4 out of 36 in total
# Progress: 11.11%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 1; metric: chebyshev; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.6368715083798883; F1-Score: 0.453781512605042;
#
# Best Performance Metrics:
# Accuracy: 0.7262569832402235; F1-Score: 0.6754966887417219;
# Already tuned 5 out of 36 in total
# Progress: 13.89%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 1; metric: chebyshev; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.6368715083798883; F1-Score: 0.453781512605042;
#
# Best Performance Metrics:
# Accuracy: 0.7262569832402235; F1-Score: 0.6754966887417219;
# Already tuned 6 out of 36 in total
# Progress: 16.67%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 5; metric: euclidean; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7597765363128491; F1-Score: 0.7225806451612903;
#
# Best Performance Metrics:
# Accuracy: 0.7597765363128491; F1-Score: 0.7225806451612903;
# Already tuned 7 out of 36 in total
# Progress: 19.44%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 5; metric: euclidean; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 8 out of 36 in total
# Progress: 22.22%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 5; metric: manhattan; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7597765363128491; F1-Score: 0.7189542483660131;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 9 out of 36 in total
# Progress: 25.0%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 5; metric: manhattan; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7777777777777778;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 10 out of 36 in total
# Progress: 27.78%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 5; metric: chebyshev; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.659217877094972; F1-Score: 0.5196850393700787;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 11 out of 36 in total
# Progress: 30.56%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 5; metric: chebyshev; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.664804469273743; F1-Score: 0.4339622641509434;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 12 out of 36 in total
# Progress: 33.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 9; metric: euclidean; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7653631284916201; F1-Score: 0.7272727272727273;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 13 out of 36 in total
# Progress: 36.11%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 9; metric: euclidean; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 14 out of 36 in total
# Progress: 38.89%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 9; metric: manhattan; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7320261437908496;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 15 out of 36 in total
# Progress: 41.67%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 9; metric: manhattan; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 16 out of 36 in total
# Progress: 44.44%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 9; metric: chebyshev; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.6983240223463687; F1-Score: 0.6086956521739131;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 17 out of 36 in total
# Progress: 47.22%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 9; metric: chebyshev; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.6927374301675978; F1-Score: 0.4954128440366973;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 18 out of 36 in total
# Progress: 50.0%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 17; metric: euclidean; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7932960893854749; F1-Score: 0.7549668874172185;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 19 out of 36 in total
# Progress: 52.78%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 17; metric: euclidean; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7714285714285715;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 20 out of 36 in total
# Progress: 55.56%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 17; metric: manhattan; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 21 out of 36 in total
# Progress: 58.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 17; metric: manhattan; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7714285714285715;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 22 out of 36 in total
# Progress: 61.11%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 17; metric: chebyshev; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.7019867549668874;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 23 out of 36 in total
# Progress: 63.89%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 17; metric: chebyshev; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6666666666666666;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 24 out of 36 in total
# Progress: 66.67%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 33; metric: euclidean; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7248322147651006;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 25 out of 36 in total
# Progress: 69.44%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 33; metric: euclidean; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.7428571428571429;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 26 out of 36 in total
# Progress: 72.22%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 33; metric: manhattan; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7877094972067039; F1-Score: 0.7466666666666667;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 27 out of 36 in total
# Progress: 75.0%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 33; metric: manhattan; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.7932960893854749; F1-Score: 0.7375886524822695;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 28 out of 36 in total
# Progress: 77.78%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 33; metric: chebyshev; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7374301675977654; F1-Score: 0.6928104575163399;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 29 out of 36 in total
# Progress: 80.56%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 33; metric: chebyshev; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.7430167597765364; F1-Score: 0.684931506849315;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 30 out of 36 in total
# Progress: 83.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 65; metric: euclidean; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7653631284916201; F1-Score: 0.72;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 31 out of 36 in total
# Progress: 86.11%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 65; metric: euclidean; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.7932960893854749; F1-Score: 0.7412587412587412;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 32 out of 36 in total
# Progress: 88.89%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 65; metric: manhattan; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7597765363128491; F1-Score: 0.7114093959731543;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 33 out of 36 in total
# Progress: 91.67%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 65; metric: manhattan; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.7464788732394366;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 34 out of 36 in total
# Progress: 94.44%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 65; metric: chebyshev; weights: distance;
#
# Current Performance Metrics:
# Accuracy: 0.7374301675977654; F1-Score: 0.6666666666666666;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 35 out of 36 in total
# Progress: 97.22%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_neighbors: 65; metric: chebyshev; weights: uniform;
#
# Current Performance Metrics:
# Accuracy: 0.7039106145251397; F1-Score: 0.5619834710743802;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Already tuned 36 out of 36 in total
# Progress: 100.0%
# ----------------------------
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7769784172661871;
# Best Performance Parameter Combination:
# n_neighbors: 9; metric: euclidean; weights: uniform;
