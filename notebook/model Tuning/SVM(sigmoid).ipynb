# %%
import pandas as pd
from sklearn.svm import SVC
import warnings
import sys
# Out:
# /Users/devin/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
warnings.filterwarnings('ignore')

# %%
sys.path.append('../../privatePackage')

# %%
from DevinMengTuner import DevinMengTuner

# %%
tunable_parameters = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'gamma': (0.001, 0.01, 0.1, 1, 10, 100),
    'tol': (0.00001, 0.0001, 0.001, 0.01, 0.1),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'coef0': (0.0, 0.1, 0.5, 1.0)
}

# %%
non_tunable_parameters = {
    'kernel': 'sigmoid',
    'class_weight': 'balanced'
}

# %%
train_X = pd.read_csv('../../data/curated/final_train_X.csv')
train_Y = pd.read_csv('../../data/curated/train_Y.csv')
val_X = pd.read_csv('../../data/curated/final_val_X.csv')
val_Y = pd.read_csv('../../data/curated/val_Y.csv')

# %%
from sklearn.svm import SVC as clf

# %%
model = clf()

# %%
tuner = DevinMengTuner()
tuner.set_data(train_X = train_X, train_Y = train_Y, test_X = val_X, test_Y = val_Y)
tuner.set_model(model=model, model_type='Classification')
tuner.set_parameters(tunable_parameters=tunable_parameters, non_tunable_parameters=non_tunable_parameters)
# Out:
# DevinMengTuner initialised

# %%
tuner.tune()
# Out:
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 50; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 1 out of 5040 in total
# Progress: 0.02%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 50; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 2 out of 5040 in total
# Progress: 0.04%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 50; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 3 out of 5040 in total
# Progress: 0.06%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 50; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 4 out of 5040 in total
# Progress: 0.08%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 100; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 5 out of 5040 in total
# Progress: 0.1%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 100; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 6 out of 5040 in total
# Progress: 0.12%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 100; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 7 out of 5040 in total
# Progress: 0.14%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 100; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 8 out of 5040 in total
# Progress: 0.16%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 200; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 9 out of 5040 in total
# Progress: 0.18%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 200; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 10 out of 5040 in total
# Progress: 0.2%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 200; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 11 out of 5040 in total
# Progress: 0.22%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 200; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 12 out of 5040 in total
# Progress: 0.24%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 400; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 13 out of 5040 in total
# Progress: 0.26%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 400; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 14 out of 5040 in total
# Progress: 0.28%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 400; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 15 out of 5040 in total
# Progress: 0.3%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 400; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 16 out of 5040 in total
# Progress: 0.32%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 800; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 17 out of 5040 in total
# Progress: 0.34%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 800; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 18 out of 5040 in total
# Progress: 0.36%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 800; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 19 out of 5040 in total
# Progress: 0.38%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 800; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 20 out of 5040 in total
# Progress: 0.4%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 1600; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 21 out of 5040 in total
# Progress: 0.42%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 1600; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 22 out of 5040 in total
# Progress: 0.44%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 1600; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 23 out of 5040 in total
# Progress: 0.46%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 1e-05; max_iter: 1600; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 24 out of 5040 in total
# Progress: 0.48%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 50; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 25 out of 5040 in total
# Progress: 0.5%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 50; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 26 out of 5040 in total
# Progress: 0.52%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 50; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 27 out of 5040 in total
# Progress: 0.54%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 50; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 28 out of 5040 in total
# Progress: 0.56%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 100; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 29 out of 5040 in total
# Progress: 0.58%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 100; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 30 out of 5040 in total
# Progress: 0.6%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 100; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 31 out of 5040 in total
# Progress: 0.62%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 100; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 32 out of 5040 in total
# Progress: 0.63%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 200; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 33 out of 5040 in total
# Progress: 0.65%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 200; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 34 out of 5040 in total
# Progress: 0.67%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 200; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 35 out of 5040 in total
# Progress: 0.69%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 200; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 36 out of 5040 in total
# Progress: 0.71%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 400; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 37 out of 5040 in total
# Progress: 0.73%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 400; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 38 out of 5040 in total
# Progress: 0.75%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 400; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 39 out of 5040 in total
# Progress: 0.77%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 400; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 40 out of 5040 in total
# Progress: 0.79%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 800; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 41 out of 5040 in total
# Progress: 0.81%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 800; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 42 out of 5040 in total
# Progress: 0.83%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 800; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 43 out of 5040 in total
# Progress: 0.85%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 800; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 44 out of 5040 in total
# Progress: 0.87%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 1600; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 45 out of 5040 in total
# Progress: 0.89%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 1600; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 46 out of 5040 in total
# Progress: 0.91%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 1600; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 47 out of 5040 in total
# Progress: 0.93%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.0001; max_iter: 1600; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 48 out of 5040 in total
# Progress: 0.95%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 50; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 49 out of 5040 in total
# Progress: 0.97%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 50; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 50 out of 5040 in total
# Progress: 0.99%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 50; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 51 out of 5040 in total
# Progress: 1.01%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 50; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 52 out of 5040 in total
# Progress: 1.03%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 100; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 53 out of 5040 in total
# Progress: 1.05%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 100; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 54 out of 5040 in total
# Progress: 1.07%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 100; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 55 out of 5040 in total
# Progress: 1.09%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 100; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 56 out of 5040 in total
# Progress: 1.11%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 200; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 57 out of 5040 in total
# Progress: 1.13%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 200; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 58 out of 5040 in total
# Progress: 1.15%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 200; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 59 out of 5040 in total
# Progress: 1.17%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 200; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 60 out of 5040 in total
# Progress: 1.19%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 400; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 61 out of 5040 in total
# Progress: 1.21%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 400; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 62 out of 5040 in total
# Progress: 1.23%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 400; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 63 out of 5040 in total
# Progress: 1.25%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 400; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 64 out of 5040 in total
# Progress: 1.27%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 800; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 65 out of 5040 in total
# Progress: 1.29%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 800; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 66 out of 5040 in total
# Progress: 1.31%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 800; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 67 out of 5040 in total
# Progress: 1.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 800; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 68 out of 5040 in total
# Progress: 1.35%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 1600; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 69 out of 5040 in total
# Progress: 1.37%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 1600; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 70 out of 5040 in total
# Progress: 1.39%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 1600; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 71 out of 5040 in total
# Progress: 1.41%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.001; max_iter: 1600; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 72 out of 5040 in total
# Progress: 1.43%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 50; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 73 out of 5040 in total
# Progress: 1.45%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 50; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 74 out of 5040 in total
# Progress: 1.47%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 50; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 75 out of 5040 in total
# Progress: 1.49%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 50; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 76 out of 5040 in total
# Progress: 1.51%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 100; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 77 out of 5040 in total
# Progress: 1.53%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 100; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 78 out of 5040 in total
# Progress: 1.55%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 100; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 79 out of 5040 in total
# Progress: 1.57%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 100; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 80 out of 5040 in total
# Progress: 1.59%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 200; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 81 out of 5040 in total
# Progress: 1.61%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 200; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 82 out of 5040 in total
# Progress: 1.63%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 200; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 83 out of 5040 in total
# Progress: 1.65%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 200; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 84 out of 5040 in total
# Progress: 1.67%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 400; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 85 out of 5040 in total
# Progress: 1.69%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 400; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 86 out of 5040 in total
# Progress: 1.71%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 400; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 87 out of 5040 in total
# Progress: 1.73%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 400; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 88 out of 5040 in total
# Progress: 1.75%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 800; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 89 out of 5040 in total
# Progress: 1.77%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 800; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 90 out of 5040 in total
# Progress: 1.79%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 800; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 91 out of 5040 in total
# Progress: 1.81%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 800; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 92 out of 5040 in total
# Progress: 1.83%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 1600; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 93 out of 5040 in total
# Progress: 1.85%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 1600; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 94 out of 5040 in total
# Progress: 1.87%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 1600; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 95 out of 5040 in total
# Progress: 1.88%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.01; max_iter: 1600; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 96 out of 5040 in total
# Progress: 1.9%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 50; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 97 out of 5040 in total
# Progress: 1.92%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 50; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 98 out of 5040 in total
# Progress: 1.94%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 50; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 99 out of 5040 in total
# Progress: 1.96%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 50; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 100 out of 5040 in total
# Progress: 1.98%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 100; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 101 out of 5040 in total
# Progress: 2.0%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 100; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 102 out of 5040 in total
# Progress: 2.02%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 100; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 103 out of 5040 in total
# Progress: 2.04%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 100; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 104 out of 5040 in total
# Progress: 2.06%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 200; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 105 out of 5040 in total
# Progress: 2.08%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 200; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 106 out of 5040 in total
# Progress: 2.1%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 200; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 107 out of 5040 in total
# Progress: 2.12%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 200; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 108 out of 5040 in total
# Progress: 2.14%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 400; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 109 out of 5040 in total
# Progress: 2.16%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 400; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 110 out of 5040 in total
# Progress: 2.18%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 400; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 111 out of 5040 in total
# Progress: 2.2%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 400; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 112 out of 5040 in total
# Progress: 2.22%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 800; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 113 out of 5040 in total
# Progress: 2.24%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 800; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 114 out of 5040 in total
# Progress: 2.26%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 800; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 115 out of 5040 in total
# Progress: 2.28%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 800; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 116 out of 5040 in total
# Progress: 2.3%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 1600; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 117 out of 5040 in total
# Progress: 2.32%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 1600; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 118 out of 5040 in total
# Progress: 2.34%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 1600; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 119 out of 5040 in total
# Progress: 2.36%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.001; tol: 0.1; max_iter: 1600; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 120 out of 5040 in total
# Progress: 2.38%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.01; tol: 1e-05; max_iter: 50; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 121 out of 5040 in total
# Progress: 2.4%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.01; tol: 1e-05; max_iter: 50; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 122 out of 5040 in total
# Progress: 2.42%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.01; tol: 1e-05; max_iter: 50; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 123 out of 5040 in total
# Progress: 2.44%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.01; tol: 1e-05; max_iter: 50; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 124 out of 5040 in total
# Progress: 2.46%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.01; tol: 1e-05; max_iter: 100; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 125 out of 5040 in total
# Progress: 2.48%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.01; tol: 1e-05; max_iter: 100; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 126 out of 5040 in total
# Progress: 2.5%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.01; tol: 1e-05; max_iter: 100; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 127 out of 5040 in total
# Progress: 2.52%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.01; tol: 1e-05; max_iter: 100; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 128 out of 5040 in total
# Progress: 2.54%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.01; tol: 1e-05; max_iter: 200; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
#
# Best Performance Metrics:
# Accuracy: 0.4134078212290503; F1-Score: 0.5849802371541502;
# Already tuned 129 out of 5040 in total
# Progress: 2.56%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 0.0001; gamma: 0.01; tol: 1e-05; max_iter: 200; coef0: 0.1;
#
# Current Performance Metrics:
# ...
#
# Current Performance Metrics:
# Accuracy: 0.553072625698324; F1-Score: 0.6396396396396397;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 4996 out of 5040 in total
# Progress: 99.13%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 100; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.547486033519553; F1-Score: 0.6267281105990783;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 4997 out of 5040 in total
# Progress: 99.15%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 100; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5363128491620112; F1-Score: 0.6103286384976526;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 4998 out of 5040 in total
# Progress: 99.17%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 100; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.5363128491620112; F1-Score: 0.6210045662100456;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 4999 out of 5040 in total
# Progress: 99.19%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 100; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.5363128491620112; F1-Score: 0.6210045662100456;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5000 out of 5040 in total
# Progress: 99.21%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 200; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.7150837988826816; F1-Score: 0.6751592356687898;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5001 out of 5040 in total
# Progress: 99.23%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 200; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5002 out of 5040 in total
# Progress: 99.25%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 200; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.7094972067039106; F1-Score: 0.6578947368421053;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5003 out of 5040 in total
# Progress: 99.27%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 200; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.7150837988826816; F1-Score: 0.6871165644171779;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5004 out of 5040 in total
# Progress: 99.29%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 400; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5005 out of 5040 in total
# Progress: 99.31%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 400; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5006 out of 5040 in total
# Progress: 99.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 400; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5007 out of 5040 in total
# Progress: 99.35%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 400; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5008 out of 5040 in total
# Progress: 99.37%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 800; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5009 out of 5040 in total
# Progress: 99.38%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 800; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5010 out of 5040 in total
# Progress: 99.4%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 800; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5011 out of 5040 in total
# Progress: 99.42%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 800; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5012 out of 5040 in total
# Progress: 99.44%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 1600; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5013 out of 5040 in total
# Progress: 99.46%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 1600; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5014 out of 5040 in total
# Progress: 99.48%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 1600; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5015 out of 5040 in total
# Progress: 99.5%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.01; max_iter: 1600; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5016 out of 5040 in total
# Progress: 99.52%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 50; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.553072625698324; F1-Score: 0.6428571428571429;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5017 out of 5040 in total
# Progress: 99.54%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 50; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.547486033519553; F1-Score: 0.6367713004484304;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5018 out of 5040 in total
# Progress: 99.56%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 50; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.553072625698324; F1-Score: 0.6396396396396397;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5019 out of 5040 in total
# Progress: 99.58%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 50; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.553072625698324; F1-Score: 0.6396396396396397;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5020 out of 5040 in total
# Progress: 99.6%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 100; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.547486033519553; F1-Score: 0.6267281105990783;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5021 out of 5040 in total
# Progress: 99.62%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 100; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5363128491620112; F1-Score: 0.6103286384976526;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5022 out of 5040 in total
# Progress: 99.64%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 100; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.5363128491620112; F1-Score: 0.6210045662100456;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5023 out of 5040 in total
# Progress: 99.66%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 100; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.5363128491620112; F1-Score: 0.6210045662100456;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5024 out of 5040 in total
# Progress: 99.68%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 200; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.7150837988826816; F1-Score: 0.6751592356687898;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5025 out of 5040 in total
# Progress: 99.7%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 200; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5026 out of 5040 in total
# Progress: 99.72%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 200; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.7094972067039106; F1-Score: 0.6578947368421053;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5027 out of 5040 in total
# Progress: 99.74%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 200; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.7150837988826816; F1-Score: 0.6871165644171779;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5028 out of 5040 in total
# Progress: 99.76%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 400; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5029 out of 5040 in total
# Progress: 99.78%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 400; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5030 out of 5040 in total
# Progress: 99.8%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 400; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5031 out of 5040 in total
# Progress: 99.82%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 400; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5032 out of 5040 in total
# Progress: 99.84%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 800; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5033 out of 5040 in total
# Progress: 99.86%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 800; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5034 out of 5040 in total
# Progress: 99.88%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 800; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5035 out of 5040 in total
# Progress: 99.9%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 800; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5036 out of 5040 in total
# Progress: 99.92%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 1600; coef0: 0.0;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5037 out of 5040 in total
# Progress: 99.94%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 1600; coef0: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6715328467153284;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5038 out of 5040 in total
# Progress: 99.96%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 1600; coef0: 0.5;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5039 out of 5040 in total
# Progress: 99.98%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# C: 100; gamma: 100; tol: 0.1; max_iter: 1600; coef0: 1.0;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6857142857142857;
#
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Already tuned 5040 out of 5040 in total
# Progress: 100.0%
# ----------------------------
# Best Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.76;
# Best Performance Parameter Combination:
# C: 0.01; gamma: 0.1; tol: 0.1; max_iter: 800; coef0: 0.5;
