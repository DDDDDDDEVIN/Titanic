# %%
import pandas as pd
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
train_X = pd.read_csv('../../data/curated/final_train_X.csv')
train_Y = pd.read_csv('../../data/curated/train_Y.csv')
val_X = pd.read_csv('../../data/curated/final_val_X.csv')
val_Y = pd.read_csv('../../data/curated/val_Y.csv')

# %%
parameter_choices = {
    'n_estimators': (25, 50, 100, 200),
    'max_depth': (2,4,8,16),
    'learning_rate': (0.001, 0.01, 0.1, 1),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'max_bin': (64, 256),
    'reg_lambda': (0.001, 0.01, 0.1, 1)
}

# %%
from catboost import CatBoostClassifier as clf
model = clf(random_state=42, verbose=False)
grid_search = GridSearchCV(estimator=model, param_grid=parameter_choices, scoring='accuracy', cv=5, verbose=3)
grid_search.fit(train_X, train_Y)
# Out:
# Fitting 5 folds for each of 2560 candidates, totalling 12800 fits
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.4;, score=0.754 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.4;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.4;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.55;, score=0.797 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.55;, score=0.790 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.55;, score=0.761 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.55;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.7;, score=0.790 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.7;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.7;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.85;, score=0.790 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.85;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=0.85;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=1;, score=0.797 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=1;, score=0.804 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=1;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=1;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.001, subsample=1;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.4;, score=0.754 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.4;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.4;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.55;, score=0.797 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.55;, score=0.790 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.55;, score=0.761 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.55;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.7;, score=0.790 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.7;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.7;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.85;, score=0.790 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.85;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=0.85;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=1;, score=0.797 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=1;, score=0.804 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=1;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=1;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.01, subsample=1;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.4;, score=0.754 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.4;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.4;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.55;, score=0.797 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.55;, score=0.790 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.55;, score=0.761 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.55;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.7;, score=0.790 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.7;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.7;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.85;, score=0.790 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.85;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=0.85;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=1;, score=0.797 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=1;, score=0.804 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=1;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=1;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=0.1, subsample=1;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.4;, score=0.754 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.4;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.4;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.55;, score=0.797 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.55;, score=0.790 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.55;, score=0.761 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.55;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.7;, score=0.790 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.7;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.7;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.85;, score=0.790 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.85;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=0.85;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=1;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=1;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=1;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=1;, score=0.754 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=25, reg_lambda=1, subsample=1;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.4;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.4;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.4;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.55;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.55;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.7;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.7;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.7;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.85;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=0.85;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=1;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=1;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=1;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=1;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.001, subsample=1;, score=0.817 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.4;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.4;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.4;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.55;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.55;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.7;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.7;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.7;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.85;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=0.85;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=1;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=1;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=1;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=1;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.01, subsample=1;, score=0.817 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.4;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.4;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.4;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.55;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.55;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.7;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.7;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.7;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.85;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=0.85;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=1;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=1;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=1;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=1;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=0.1, subsample=1;, score=0.817 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.4;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.4;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.4;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.55;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.55;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.7;, score=0.797 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.7;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.7;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.85;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=0.85;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=1;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=1;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=1;, score=0.761 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=1;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=50, reg_lambda=1, subsample=1;, score=0.817 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.4;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.4;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.4;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.55;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.55;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.55;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.7;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.7;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.7;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.85;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.85;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=0.85;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=1;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=1;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=1;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=1;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.001, subsample=1;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.4;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.4;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.4;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.55;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.55;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.55;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.7;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.7;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.7;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.85;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.85;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=0.85;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=1;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=1;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=1;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=1;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.01, subsample=1;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.4;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.4;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.4;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.55;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.55;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.55;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.7;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.7;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.7;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.85;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.85;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=0.85;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=1;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=1;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=1;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=1;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=0.1, subsample=1;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.4;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.4;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.4;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.4;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.4;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.55;, score=0.818 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.55;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.55;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.55;, score=0.746 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.55;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.7;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.7;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.7;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.7;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.7;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.85;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.85;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.85;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.85;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=0.85;, score=0.831 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=1;, score=0.804 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=1;, score=0.811 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=1;, score=0.768 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=1;, score=0.739 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=100, reg_lambda=1, subsample=1;, score=0.824 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.4;, score=0.811 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.4;, score=0.804 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.4;, score=0.761 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.4;, score=0.739 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.4;, score=0.824 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.55;, score=0.811 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.55;, score=0.811 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.55;, score=0.761 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.55;, score=0.739 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.55;, score=0.824 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.7;, score=0.804 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.7;, score=0.811 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.7;, score=0.768 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.7;, score=0.739 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.7;, score=0.824 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.85;, score=0.804 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.85;, score=0.804 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.85;, score=0.768 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.85;, score=0.739 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=0.85;, score=0.824 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=1;, score=0.804 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=1;, score=0.811 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=1;, score=0.768 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=1;, score=0.739 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.001, subsample=1;, score=0.824 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.4;, score=0.804 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.4;, score=0.804 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.4;, score=0.761 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.4;, score=0.739 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.4;, score=0.824 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.55;, score=0.804 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.55;, score=0.811 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.55;, score=0.768 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.55;, score=0.739 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.55;, score=0.824 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.7;, score=0.804 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.7;, score=0.811 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.7;, score=0.775 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.7;, score=0.739 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.7;, score=0.824 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.85;, score=0.804 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=2, n_estimators=200, reg_lambda=0.01, subsample=0.85;, score=0.811 total time=   0.1s
# ...
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.4;, score=0.796 total time=  27.9s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.4;, score=0.838 total time=  25.5s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.55;, score=0.818 total time=  25.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.55;, score=0.818 total time=  26.9s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.55;, score=0.852 total time=  25.0s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.55;, score=0.789 total time=  25.6s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.55;, score=0.838 total time=  26.0s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.7;, score=0.818 total time=  26.4s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.7;, score=0.804 total time=  25.2s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.7;, score=0.824 total time=  26.6s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.7;, score=0.789 total time=  27.4s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.7;, score=0.838 total time=  28.1s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.85;, score=0.818 total time=  27.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.85;, score=0.818 total time=  27.5s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.85;, score=0.824 total time=  27.5s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.85;, score=0.796 total time=  26.9s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=0.85;, score=0.845 total time=  27.7s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=1;, score=0.825 total time=  28.0s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=1;, score=0.825 total time=  27.6s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=1;, score=0.838 total time=  27.3s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=1;, score=0.810 total time=  26.8s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.01, subsample=1;, score=0.817 total time=  26.6s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.4;, score=0.804 total time=  27.5s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.4;, score=0.811 total time=  26.9s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.4;, score=0.824 total time=  26.7s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.4;, score=0.796 total time=  26.8s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.4;, score=0.838 total time=  27.1s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.55;, score=0.818 total time=  26.9s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.55;, score=0.818 total time=  28.2s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.55;, score=0.838 total time=  27.5s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.55;, score=0.796 total time=  27.6s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.55;, score=0.838 total time=  27.1s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.7;, score=0.825 total time=  27.5s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.7;, score=0.825 total time=  27.4s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.7;, score=0.824 total time=  27.4s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.7;, score=0.796 total time=  26.6s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.7;, score=0.845 total time=  27.4s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.85;, score=0.818 total time=  26.7s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.85;, score=0.818 total time=  27.7s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.85;, score=0.838 total time=  27.7s
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.85;, score=0.782 total time=  27.5s
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=0.85;, score=0.831 total time=  28.5s
# [CV 1/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=1;, score=0.818 total time=  27.7s
# [CV 2/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=1;, score=0.825 total time=  27.9s
# [CV 3/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=1;, score=0.838 total time=42.7min
# [CV 4/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=1;, score=0.789 total time=17.4min
# [CV 5/5] END learning_rate=0.001, max_bin=64, max_depth=16, n_estimators=100, reg_lambda=0.1, subsample=1;, score=0.817 total time=  30.1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       2 model = clf(random_state=42, verbose=False)
#       3 grid_search = GridSearchCV(estimator=model, param_grid=parameter_choices, scoring='accuracy', cv=5, verbose=3)
# ----> 4 grid_search.fit(train_X, train_Y)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1018, in BaseSearchCV.fit(self, X, y, **params)
#    1012     results = self._format_results(
#    1013         all_candidate_params, n_splits, all_out, all_more_results
#    1014     )
#    1016     return results
# -> 1018 self._run_search(evaluate_candidates)
#    1020 # multimetric is determined here because in the case of a callable
#    1021 # self.scoring the return type is only known after calling
#    1022 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1572, in GridSearchCV._run_search(self, evaluate_candidates)
#    1570 def _run_search(self, evaluate_candidates):
#    1571     """Search all candidates in param_grid"""
# -> 1572     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:964, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     956 if self.verbose > 0:
#     957     print(
#     958         "Fitting {0} folds for each of {1} candidates,"
#     959         " totalling {2} fits".format(
#     960             n_splits, n_candidates, n_candidates * n_splits
#     961         )
#     962     )
# --> 964 out = parallel(
#     965     delayed(_fit_and_score)(
#     966         clone(base_estimator),
#     967         X,
#     968         y,
#     969         train=train,
#     970         test=test,
#     971         parameters=parameters,
#     972         split_progress=(split_idx, n_splits),
#     973         candidate_progress=(cand_idx, n_candidates),
#     974         **fit_and_score_kwargs,
#     975     )
#     976     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     977         enumerate(candidate_params),
#     978         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     979     )
#     980 )
#     982 if len(out) < 1:
#     983     raise ValueError(
#     984         "No fits were performed. "
#     985         "Was the CV iterator empty? "
#     986         "Were there no candidates?"
#     987     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File ~/anaconda3/lib/python3.11/site-packages/catboost/core.py:5220, in CatBoostClassifier.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5217 if 'loss_function' in params:
#    5218     CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
# -> 5220 self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5221           eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5222           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5223 return self
#
# File ~/anaconda3/lib/python3.11/site-packages/catboost/core.py:2400, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2397 allow_clear_pool = train_params["allow_clear_pool"]
#    2399 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2400     self._train(
#    2401         train_pool,
#    2402         train_params["eval_sets"],
#    2403         params,
#    2404         allow_clear_pool,
#    2405         train_params["init_model"]
#    2406     )
#    2408 # Have property feature_importance possibly set
#    2409 loss = self._object._get_loss_function_name()
#
# File ~/anaconda3/lib/python3.11/site-packages/catboost/core.py:1780, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1779 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1780     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1781     self._set_trained_model_attributes()
#
# File _catboost.pyx:4833, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4882, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
print(grid_search.best_estimator_)
print(grid_search.best_score_)
# Out:
# AdaBoostClassifier(learning_rate=0.1, n_estimators=800, random_state=42)
# 0.8047473653107456
