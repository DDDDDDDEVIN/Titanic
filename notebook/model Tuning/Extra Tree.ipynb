# %%
import pandas as pd
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
import warnings
import sys
import json

# %%
warnings.filterwarnings('ignore')

# %%
sys.path.append('../../privatePackage')

# %%
from DevinMengTuner import DevinMengTuner

# %%
MODEL_NAME = 'ET'

# %%
train_X = pd.read_csv('../../data/curated/final_train_X.csv')
train_Y = pd.read_csv('../../data/curated/train_Y.csv')
val_X = pd.read_csv('../../data/curated/final_val_X.csv')
val_Y = pd.read_csv('../../data/curated/val_Y.csv')

# %%
tunable_parameters = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_parameters = {
                                    'random_state': 42,
                                    'n_jobs': -1,
                                    'bootstrap': True
                                    }

# %%
from sklearn.ensemble import ExtraTreesClassifier as clf
model = clf()

# %%
tuner = DevinMengTuner()
tuner.set_model(model=model, model_type='Classification', model_name = MODEL_NAME)
tuner.set_parameters(tunable_parameters=tunable_parameters, non_tunable_parameters=non_tunable_parameters)
tuner.set_data(train_X = train_X, train_Y = train_Y, test_X=val_X, test_Y=val_Y)
tuner.tune()
# Out:
# DevinMengTuner initialised
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.4; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
#
# Best Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
# Already tuned 1 out of 5250 in total
# Progress: 0.02%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.4; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
#
# Best Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
# Already tuned 2 out of 5250 in total
# Progress: 0.04%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.4; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
#
# Best Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
# Already tuned 3 out of 5250 in total
# Progress: 0.06%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.4; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.75;
#
# Best Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
# Already tuned 4 out of 5250 in total
# Progress: 0.08%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.4; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.7272727272727273;
#
# Best Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
# Already tuned 5 out of 5250 in total
# Progress: 0.1%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.55; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.7932960893854749; F1-Score: 0.7412587412587412;
#
# Best Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
# Already tuned 6 out of 5250 in total
# Progress: 0.11%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.55; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.7932960893854749; F1-Score: 0.7412587412587412;
#
# Best Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
# Already tuned 7 out of 5250 in total
# Progress: 0.13%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.55; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.7932960893854749; F1-Score: 0.7412587412587412;
#
# Best Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
# Already tuned 8 out of 5250 in total
# Progress: 0.15%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.55; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.7877094972067039; F1-Score: 0.7323943661971831;
#
# Best Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
# Already tuned 9 out of 5250 in total
# Progress: 0.17%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.55; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.7272727272727273;
#
# Best Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
# Already tuned 10 out of 5250 in total
# Progress: 0.19%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.7; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7785234899328859;
#
# Best Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7785234899328859;
# Already tuned 11 out of 5250 in total
# Progress: 0.21%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.7; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7785234899328859;
#
# Best Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7785234899328859;
# Already tuned 12 out of 5250 in total
# Progress: 0.23%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.7; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7785234899328859;
#
# Best Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7785234899328859;
# Already tuned 13 out of 5250 in total
# Progress: 0.25%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.7; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7755102040816326;
#
# Best Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7785234899328859;
# Already tuned 14 out of 5250 in total
# Progress: 0.27%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.7; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.7272727272727273;
#
# Best Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7785234899328859;
# Already tuned 15 out of 5250 in total
# Progress: 0.29%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.85; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 16 out of 5250 in total
# Progress: 0.3%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.85; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 17 out of 5250 in total
# Progress: 0.32%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.85; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 18 out of 5250 in total
# Progress: 0.34%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.85; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.75;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 19 out of 5250 in total
# Progress: 0.36%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 0.85; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.7272727272727273;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 20 out of 5250 in total
# Progress: 0.38%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 1; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.6312849162011173; F1-Score: 0.1951219512195122;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 21 out of 5250 in total
# Progress: 0.4%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 1; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.6312849162011173; F1-Score: 0.1951219512195122;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 22 out of 5250 in total
# Progress: 0.42%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 1; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.6312849162011173; F1-Score: 0.1951219512195122;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 23 out of 5250 in total
# Progress: 0.44%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 1; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.6145251396648045; F1-Score: 0.12658227848101267;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 24 out of 5250 in total
# Progress: 0.46%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.4; max_features: 1; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 25 out of 5250 in total
# Progress: 0.48%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.4; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.75;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 26 out of 5250 in total
# Progress: 0.5%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.4; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.75;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 27 out of 5250 in total
# Progress: 0.51%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.4; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.7988826815642458; F1-Score: 0.75;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 28 out of 5250 in total
# Progress: 0.53%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.4; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.7932960893854749; F1-Score: 0.7412587412587412;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 29 out of 5250 in total
# Progress: 0.55%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.4; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.7272727272727273;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 30 out of 5250 in total
# Progress: 0.57%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.55; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.75177304964539;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 31 out of 5250 in total
# Progress: 0.59%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.55; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.75177304964539;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 32 out of 5250 in total
# Progress: 0.61%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.55; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.75177304964539;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 33 out of 5250 in total
# Progress: 0.63%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.55; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.75177304964539;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 34 out of 5250 in total
# Progress: 0.65%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.55; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.7272727272727273;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 35 out of 5250 in total
# Progress: 0.67%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.7; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7777777777777778;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 36 out of 5250 in total
# Progress: 0.69%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.7; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7777777777777778;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 37 out of 5250 in total
# Progress: 0.7%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.7; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7777777777777778;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 38 out of 5250 in total
# Progress: 0.72%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.7; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7552447552447552;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 39 out of 5250 in total
# Progress: 0.74%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.7; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.7272727272727273;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 40 out of 5250 in total
# Progress: 0.76%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.85; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7692307692307693;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 41 out of 5250 in total
# Progress: 0.78%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.85; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7692307692307693;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 42 out of 5250 in total
# Progress: 0.8%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.85; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7692307692307693;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned 43 out of 5250 in total
# Progress: 0.82%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 0.55; max_features: 0.85; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.8100558659217877; F1-Score: 0.7605633802816901;
#
# Best Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
# Already tuned
96%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.4; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 104 out of 5250 in total
# Progress: 1.98%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.4; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 105 out of 5250 in total
# Progress: 2.0%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.55; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 106 out of 5250 in total
# Progress: 2.02%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.55; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 107 out of 5250 in total
# Progress: 2.04%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.55; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 108 out of 5250 in total
# Progress: 2.06%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.55; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 109 out of 5250 in total
# Progress: 2.08%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.55; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 110 out of 5250 in total
# Progress: 2.1%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.7; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 111 out of 5250 in total
# Progress: 2.11%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.7; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 112 out of 5250 in total
# Progress: 2.13%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.7; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 113 out of 5250 in total
# Progress: 2.15%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.7; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 114 out of 5250 in total
# Progress: 2.17%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.7; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 115 out of 5250 in total
# Progress: 2.19%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.85; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 116 out of 5250 in total
# Progress: 2.21%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.85; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 117 out of 5250 in total
# Progress: 2.23%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.85; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 118 out of 5250 in total
# Progress: 2.25%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.85; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 119 out of 5250 in total
# Progress: 2.27%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 0.85; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 120 out of 5250 in total
# Progress: 2.29%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 1; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 121 out of 5250 in total
# Progress: 2.3%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 1; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 122 out of 5250 in total
# Progress: 2.32%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 1; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7832167832167832;
# Already tuned 123 out of 5250 in total
# Progress: 2.34%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; max_depth: 3; max_samples: 1; max_features: 1; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# ...
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5210 out of 5250 in total
# Progress: 99.24%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 0.7; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7785234899328859;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5211 out of 5250 in total
# Progress: 99.26%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 0.7; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7785234899328859;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5212 out of 5250 in total
# Progress: 99.28%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 0.7; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.8156424581005587; F1-Score: 0.7785234899328859;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5213 out of 5250 in total
# Progress: 99.3%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 0.7; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.8324022346368715; F1-Score: 0.7916666666666666;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5214 out of 5250 in total
# Progress: 99.31%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 0.7; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.7272727272727273;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5215 out of 5250 in total
# Progress: 99.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 0.85; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7712418300653595;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5216 out of 5250 in total
# Progress: 99.35%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 0.85; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7712418300653595;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5217 out of 5250 in total
# Progress: 99.37%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 0.85; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.8044692737430168; F1-Score: 0.7712418300653595;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5218 out of 5250 in total
# Progress: 99.39%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 0.85; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.8212290502793296; F1-Score: 0.7808219178082192;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5219 out of 5250 in total
# Progress: 99.41%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 0.85; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.7272727272727273;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5220 out of 5250 in total
# Progress: 99.43%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 1; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7891156462585034;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5221 out of 5250 in total
# Progress: 99.45%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 1; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7891156462585034;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5222 out of 5250 in total
# Progress: 99.47%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 1; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.8268156424581006; F1-Score: 0.7891156462585034;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5223 out of 5250 in total
# Progress: 99.49%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 1; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.7877094972067039; F1-Score: 0.7323943661971831;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5224 out of 5250 in total
# Progress: 99.5%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 0.85; max_features: 1; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5225 out of 5250 in total
# Progress: 99.52%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.4; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5226 out of 5250 in total
# Progress: 99.54%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.4; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5227 out of 5250 in total
# Progress: 99.56%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.4; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5228 out of 5250 in total
# Progress: 99.58%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.4; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5229 out of 5250 in total
# Progress: 99.6%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.4; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5230 out of 5250 in total
# Progress: 99.62%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.55; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5231 out of 5250 in total
# Progress: 99.64%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.55; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5232 out of 5250 in total
# Progress: 99.66%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.55; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5233 out of 5250 in total
# Progress: 99.68%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.55; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5234 out of 5250 in total
# Progress: 99.7%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.55; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5235 out of 5250 in total
# Progress: 99.71%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.7; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5236 out of 5250 in total
# Progress: 99.73%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.7; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5237 out of 5250 in total
# Progress: 99.75%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.7; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5238 out of 5250 in total
# Progress: 99.77%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.7; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5239 out of 5250 in total
# Progress: 99.79%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.7; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5240 out of 5250 in total
# Progress: 99.81%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.85; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5241 out of 5250 in total
# Progress: 99.83%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.85; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5242 out of 5250 in total
# Progress: 99.85%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.85; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5243 out of 5250 in total
# Progress: 99.87%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.85; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5244 out of 5250 in total
# Progress: 99.89%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 0.85; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5245 out of 5250 in total
# Progress: 99.9%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 1; ccp_alpha: 1e-08;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5246 out of 5250 in total
# Progress: 99.92%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 1; ccp_alpha: 1e-06;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5247 out of 5250 in total
# Progress: 99.94%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 1; ccp_alpha: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5248 out of 5250 in total
# Progress: 99.96%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 1; ccp_alpha: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5249 out of 5250 in total
# Progress: 99.98%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; max_depth: 192; max_samples: 1; max_features: 1; ccp_alpha: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.5865921787709497; F1-Score: 0.0;
#
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Already tuned 5250 out of 5250 in total
# Progress: 100.0%
# ----------------------------
# Best Performance Metrics:
# Accuracy: 0.8547486033519553; F1-Score: 0.8194444444444444;
# Best Performance Parameter Combination:
# n_estimators: 25; max_depth: 48; max_samples: 0.55; max_features: 0.55; ccp_alpha: 1e-08;

# %%
tuner.best_model
# Out:
# ExtraTreesClassifier(bootstrap=True, ccp_alpha=0.1, max_depth=192,
#                      max_features=1, max_samples=1, n_estimators=800, n_jobs=-1,
#                      random_state=42)
