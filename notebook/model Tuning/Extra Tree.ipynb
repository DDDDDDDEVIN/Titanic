# %%
import pandas as pd
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
import warnings
import sys
import json

# %%
warnings.filterwarnings('ignore')

# %%
sys.path.append('../../privatePackage')

# %%
from DevinMengTuner import DevinMengTuner

# %%
MODEL_NAME = 'ADA'

# %%
train_X = pd.read_csv('../../data/curated/final_train_X.csv')
train_Y = pd.read_csv('../../data/curated/train_Y.csv')
val_X = pd.read_csv('../../data/curated/final_val_X.csv')
val_Y = pd.read_csv('../../data/curated/val_Y.csv')

# %%
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'learning_rate': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100)
}
non_tunable_parameter = {
    'random_state' : 42,
}

# %%
from sklearn.ensemble import AdaBoostClassifier as clf
model = clf()

# %%
tuner = DevinMengTuner()
tuner.set_model(model=model, model_type='Classification')
tuner.set_parameters(tunable_parameters=parameter_choices, non_tunable_parameters=non_tunable_parameter)
tuner.set_data(train_X = train_X, train_Y = train_Y, test_X=val_X, test_Y=val_Y)
tuner.tune()
# Out:
# DevinMengTuner initialised
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; learning_rate: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
# Already tuned 1 out of 42 in total
# Progress: 2.38%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; learning_rate: 0.001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
# Already tuned 2 out of 42 in total
# Progress: 4.76%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; learning_rate: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
# Already tuned 3 out of 42 in total
# Progress: 7.14%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; learning_rate: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 4 out of 42 in total
# Progress: 9.52%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; learning_rate: 1;
#
# Current Performance Metrics:
# Accuracy: 0.7486033519553073; F1-Score: 0.6853146853146853;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 5 out of 42 in total
# Progress: 11.9%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; learning_rate: 10;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 6 out of 42 in total
# Progress: 14.29%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 25; learning_rate: 100;
#
# Current Performance Metrics:
# Accuracy: 0.22346368715083798; F1-Score: 0.25668449197860965;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 7 out of 42 in total
# Progress: 16.67%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 50; learning_rate: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 8 out of 42 in total
# Progress: 19.05%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 50; learning_rate: 0.001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 9 out of 42 in total
# Progress: 21.43%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 50; learning_rate: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 10 out of 42 in total
# Progress: 23.81%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 50; learning_rate: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 11 out of 42 in total
# Progress: 26.19%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 50; learning_rate: 1;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.7027027027027027;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 12 out of 42 in total
# Progress: 28.57%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 50; learning_rate: 10;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 13 out of 42 in total
# Progress: 30.95%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 50; learning_rate: 100;
#
# Current Performance Metrics:
# Accuracy: 0.22346368715083798; F1-Score: 0.25668449197860965;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 14 out of 42 in total
# Progress: 33.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 100; learning_rate: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 15 out of 42 in total
# Progress: 35.71%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 100; learning_rate: 0.001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 16 out of 42 in total
# Progress: 38.1%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 100; learning_rate: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 17 out of 42 in total
# Progress: 40.48%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 100; learning_rate: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7597765363128491; F1-Score: 0.7114093959731543;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 18 out of 42 in total
# Progress: 42.86%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 100; learning_rate: 1;
#
# Current Performance Metrics:
# Accuracy: 0.7430167597765364; F1-Score: 0.676056338028169;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 19 out of 42 in total
# Progress: 45.24%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 100; learning_rate: 10;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 20 out of 42 in total
# Progress: 47.62%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 100; learning_rate: 100;
#
# Current Performance Metrics:
# Accuracy: 0.22346368715083798; F1-Score: 0.25668449197860965;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 21 out of 42 in total
# Progress: 50.0%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 200; learning_rate: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 22 out of 42 in total
# Progress: 52.38%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 200; learning_rate: 0.001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 23 out of 42 in total
# Progress: 54.76%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 200; learning_rate: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.7653631284916201; F1-Score: 0.7123287671232876;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 24 out of 42 in total
# Progress: 57.14%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 200; learning_rate: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.7272727272727273;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 25 out of 42 in total
# Progress: 59.52%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 200; learning_rate: 1;
#
# Current Performance Metrics:
# Accuracy: 0.7094972067039106; F1-Score: 0.6388888888888888;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 26 out of 42 in total
# Progress: 61.9%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 200; learning_rate: 10;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 27 out of 42 in total
# Progress: 64.29%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 200; learning_rate: 100;
#
# Current Performance Metrics:
# Accuracy: 0.22346368715083798; F1-Score: 0.25668449197860965;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 28 out of 42 in total
# Progress: 66.67%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 400; learning_rate: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 29 out of 42 in total
# Progress: 69.05%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 400; learning_rate: 0.001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 30 out of 42 in total
# Progress: 71.43%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 400; learning_rate: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.776536312849162; F1-Score: 0.7142857142857143;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 31 out of 42 in total
# Progress: 73.81%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 400; learning_rate: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7597765363128491; F1-Score: 0.6993006993006993;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 32 out of 42 in total
# Progress: 76.19%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 400; learning_rate: 1;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6901408450704225;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 33 out of 42 in total
# Progress: 78.57%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 400; learning_rate: 10;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 34 out of 42 in total
# Progress: 80.95%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 400; learning_rate: 100;
#
# Current Performance Metrics:
# Accuracy: 0.22346368715083798; F1-Score: 0.25668449197860965;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 35 out of 42 in total
# Progress: 83.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; learning_rate: 0.0001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 36 out of 42 in total
# Progress: 85.71%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; learning_rate: 0.001;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 37 out of 42 in total
# Progress: 88.1%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; learning_rate: 0.01;
#
# Current Performance Metrics:
# Accuracy: 0.776536312849162; F1-Score: 0.7222222222222222;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 38 out of 42 in total
# Progress: 90.48%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; learning_rate: 0.1;
#
# Current Performance Metrics:
# Accuracy: 0.7541899441340782; F1-Score: 0.6944444444444444;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 39 out of 42 in total
# Progress: 92.86%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; learning_rate: 1;
#
# Current Performance Metrics:
# Accuracy: 0.7374301675977654; F1-Score: 0.6802721088435374;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 40 out of 42 in total
# Progress: 95.24%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; learning_rate: 10;
#
# Current Performance Metrics:
# Accuracy: 0.770949720670391; F1-Score: 0.7050359712230215;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 41 out of 42 in total
# Progress: 97.62%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# n_estimators: 800; learning_rate: 100;
#
# Current Performance Metrics:
# Accuracy: 0.22346368715083798; F1-Score: 0.25668449197860965;
#
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Already tuned 42 out of 42 in total
# Progress: 100.0%
# ----------------------------
# Best Performance Metrics:
# Accuracy: 0.7821229050279329; F1-Score: 0.723404255319149;
# Best Performance Parameter Combination:
# n_estimators: 25; learning_rate: 0.1;
